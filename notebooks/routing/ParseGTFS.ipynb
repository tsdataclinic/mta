# %% [markdown]
# ## Roll up GTFS data into Hourly files

# %%
# %load_ext autoreload
# %autoreload 2

from typing import List, Dict, Tuple
from google.transit import gtfs_realtime_pb2 as gtfs_rt
from protobuf_to_dict import protobuf_to_dict
import pandas as pd
import numpy as np
import sys, os
from os import listdir
from os.path import isfile, join
import re
from datetime import datetime

from pandas.io.json import json_normalize
from itertools import groupby

sys.path.insert(0, os.path.realpath('/content/jupyter/mta-accessibility/notebooks/routing'))
import GTFS_Utils as gu
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#gu.get_file_names('201906/20190601', 'ace', '20190601')[:3]
#gu.load_gtfs(['201906/20190601/gtfs_ace_20190601_072836.gtfs'])

# %%
# Out:
# typing.Tuple[pandas.core.frame.DataFrame, pandas.core.frame.DataFrame]

# %%
def parse_updates(realtime_data: List[Dict]) -> Tuple[pd.DataFrame, pd.DataFrame]:
    """
    Returns trip_updates, vehicle_updates
    """    
    vdf = df = json_normalize(realtime_data)    
    
    # Parse trip updates
    df = df[~df['trip_update.stop_time_update'].isnull()]
    idx = df.index.repeat(df['trip_update.stop_time_update'].str.len())
    df1 = pd.DataFrame({'trip_update.stop_time_update': np.concatenate(df['trip_update.stop_time_update'].values)})
    df1.index = idx
    df = df1.join(df.drop('trip_update.stop_time_update', axis=1), how='left')
    df = df.reset_index(drop=True)
    d2 = json_normalize(df['trip_update.stop_time_update'])
    df = pd.concat([d2, df.drop('trip_update.stop_time_update', axis=1)], axis=1)
    df = df.drop(list(df.filter(regex='vehicle')), axis=1) 
        
    # Parse vehicle updates
    vdf = vdf[~vdf['vehicle.trip.trip_id'].isnull()]
    vdf = vdf.drop(list(vdf.filter(regex='trip_update')), axis=1)
    return df, vdf

# %%
# %%time

file_names = gu.get_file_names('/content/jupyter/20190601', 'ace', '20190601')
feed = gtfs_rt.FeedMessage()


realtime_data = gu.load_gtfs(file_names[:1000])
realtime_data = [d for d in realtime_data if 'vehicle' in d]

vdf = json_normalize(realtime_data)    
vdf.columns = vdf.columns.str.replace('vehicle\.', '')
# vdf.columns = vdf.columns.str.replace('trip\.', '')

vdf.head()
# Out:
# /content/jupyter/mta-accessibility/notebooks/routing/GTFS_Utils.py:61: RuntimeWarning: Unexpected end-group tag: Not all data was converted
#   feed.ParseFromString(raw_str)
# CPU times: user 1min 6s, sys: 2.12 s, total: 1min 8s
# Wall time: 1min 8s
#         id  current_status  current_stop_sequence stop_id     timestamp  \
# 0  000002A             NaN                   29.0     H04  1.559389e+09
# 1  000004A             NaN                   28.0     H03  1.559389e+09
# 2  000006A             NaN                   28.0     A24           NaN
# 3  000008A             NaN                   27.0     A05  1.559389e+09
# 4  000010A             NaN                   20.0     A48           NaN
#
#   trip.route_id trip.start_date trip.start_time trip.trip_id
# 0             A        20190601        05:55:31  035551_A..S
# 1             A        20190601        06:03:01  036301_A..S
# 2             A        20190601        06:11:30  037150_A..N
# 3             A        20190601        06:22:00  038200_A..N
# 4             A        20190601        06:29:35  038958_A..S

# %%
#vdf.groupby('trip.trip_id')['stop_id'].count()
vdf
# Out:
# trip.trip_id
# 000000_FS..S    43
# 000050_E..N     43
# 000200_A..N     40
# 000300_H..S     38
# 000950_A..S     33
# 000950_FS..N    33
# 001250_E..N     31
# 001350_E..S     30
# 002000_A..N     27
# 002000_FS..S    27
# 002000_H..N     27
# 002200_A..N     25
# 002450_E..N     22
# 002600_H..S     22
# 002950_A..S     20
# 002950_FS..N    20
# 003350_E..S     18
# 003750_E..N     15
# 004000_A..N     13
# 004000_FS..S    13
# 004150_H..N     10
# 004200_A..N     10
# 004950_A..S      8
# 004950_E..N      8
# 004950_FS..N     8
# 005000_H..S      8
# 005350_E..S      3
# 005650_A..S      2
# 005650_H..N      2
# 010198_H..N     19
#                 ..
# 140550_E..S     29
# 140600_E..N     73
# 140900_FS..N    22
# 140950_FS..N    48
# 141000_A..S     54
# 141100_E..S     54
# 141146_H..N     19
# 141150_H..N     50
# 141200_A..N     68
# 141350_A..S     17
# 141650_E..N     65
# 141650_E..S     16
# 141800_A..N     65
# 141900_H..S     56
# 142000_FS..S    53
# 142200_A..S     52
# 142300_E..S     50
# 142400_E..S     10
# 142500_A..S     10
# 142700_A..N     46
# 142785_A..N      9
# 142850_E..N     44
# 142851_E..N      8
# 142900_FS..N    10
# 142950_FS..N    40
# 143000_A..N     47
# 143500_A..N      2
# 143550_E..S     45
# 143700_A..S     44
# 143850_H..N     44
# Name: stop_id, Length: 1410, dtype: int64

# %%
# %%time
import warnings
import tables

# TODO add better logging of corrupted GTFS files.
# TODO fix this sketch suppressed warning.
warnings.simplefilter('ignore', tables.NaturalNameWarning)

# Take GTFS files and group them by hour. Write them back as pickled dataframes.
def create_hourly_files(data_dir: str, output_dir: str):
    file_name_pat = re.compile('gtfs_([a-zA-Z0-9]+)_([0-9]+)_([0-9]+)\.gtfs')
        
    # All files in given data_dir
    all_files = [f for f in listdir(data_dir) if isfile(join(data_dir, f))]
        
    # Sort key on the hour part of the timestamp
    def sort_key(x):
        file_name_pat = re.compile('.*gtfs_([a-zA-Z0-9]+)_([0-9]+)_([0-9]+)\.gtfs')
        regex_group = file_name_pat.match(x)
        time = regex_group.group(3)
        return time[:2]

    date = data_dir.partition('/')[2]
    all_files = list(map(lambda x: '{}/{}'.format(data_dir, x), all_files))
    all_files.sort(key=sort_key)
    for hour,g in groupby(all_files, key=sort_key):    
        output_name = '{}_{}.pkl'.format(date, hour)
        output_path = output_dir + '/' + output_name

        start_time = datetime.now()
        realtime_data = gu.load_gtfs(list(g))
        df = parse_trip_updates(realtime_data)   
        df.to_pickle(output_path)
        end_time = datetime.now()        
        print('Processing file {} took {}'.format(output_name, (end_time - start_time)))
# Out:
# CPU times: user 61.5 ms, sys: 24.2 ms, total: 85.7 ms
# Wall time: 1.25 s

# %%
# %%time

parent_dir = '201906'

dirs = [f for f in listdir(parent_dir) if not isfile(data_dir)]
dirs.remove('zipped')
dirs.remove('20190601')

for data_dir in dirs:
    start_time = datetime.now()
    create_hourly_files(parent_dir + '/' + data_dir, 'hourly')
    end_time = datetime.now()        
    print('----Processing dir {} took {}'.format(data_dir, (end_time - start_time)))
# Out:
# Processing file 20190629_03.pkl took 0:00:00.065217
# Processing file 20190629_04.pkl took 0:01:44.459757
# Processing file 20190629_05.pkl took 0:02:58.726642
# Processing file 20190629_06.pkl took 0:03:37.850944
# Processing file 20190629_07.pkl took 0:04:04.695024
# Processing file 20190629_08.pkl took 0:04:08.131597
# Processing file 20190629_09.pkl took 0:04:01.155779
# Processing file 20190629_10.pkl took 0:03:43.858287
# Processing file 20190629_11.pkl took 0:03:34.815877
# Processing file 20190629_12.pkl took 0:03:33.339774
# Processing file 20190629_13.pkl took 0:03:54.627952
# Error with file 201906/20190629/gtfs_ace_20190629_140835.gtfs
# Processing file 20190629_14.pkl took 0:03:42.289809
# Processing file 20190629_15.pkl took 0:03:40.690832
# Error with file 201906/20190629/gtfs_nqrw_20190629_161144.gtfs
# Processing file 20190629_16.pkl took 0:03:35.248919
# Processing file 20190629_17.pkl took 0:03:29.295154
# /opt/conda/envs/py3/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: Unexpected end-group tag: Not all data was converted
#   from ipykernel import kernelapp as app
# Processing file 20190629_18.pkl took 0:03:11.339049
# Error with file 201906/20190629/gtfs_ace_20190629_193812.gtfs
# Processing file 20190629_19.pkl took 0:02:52.909652
# Processing file 20190629_20.pkl took 0:02:41.842424
# Processing file 20190629_21.pkl took 0:02:32.457324
# Processing file 20190629_22.pkl took 0:02:25.944983
# Processing file 20190629_23.pkl took 0:02:05.238049
# ----Processing dir 20190629 took 1:05:40.150022
# Processing file 20190602_03.pkl took 0:00:00.066349
# Processing file 20190602_04.pkl took 0:01:37.059183
# Processing file 20190602_05.pkl took 0:02:26.101203
# Error with file 201906/20190602/gtfs_7_20190602_062811.gtfs
# Processing file 20190602_06.pkl took 0:02:38.304160
# Processing file 20190602_07.pkl took 0:03:02.649863
# Processing file 20190602_08.pkl took 0:03:11.004930
# Processing file 20190602_09.pkl took 0:03:20.661430
# Processing file 20190602_10.pkl took 0:03:11.521656
# Error with file 201906/20190602/gtfs_nqrw_20190602_115534.gtfs
# Processing file 20190602_11.pkl took 0:03:12.595116
# Processing file 20190602_12.pkl took 0:03:14.263844
# Processing file 20190602_13.pkl took 0:03:17.691526
# Processing file 20190602_14.pkl took 0:03:09.031850
# Processing file 20190602_15.pkl took 0:03:07.218918
# Processing file 20190602_16.pkl took 0:03:11.130042
# Processing file 20190602_17.pkl took 0:02:59.239752
# Processing file 20190602_18.pkl took 0:02:54.439109
gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_092131.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_094328.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_092202.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_094808.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_091405.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_092916.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_093107.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_094118.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_091831.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_091432.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_092842.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_095328.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_093407.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_092826.gtfs
# Processing file 20190603_09.pkl took 0:05:00.530205
# Error with file 201906/20190603/gtfs_ace_20190603_103005.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_105142.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_100009.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_104453.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_105743.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_105743.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_102531.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_104112.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_104852.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_100720.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_105025.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_102831.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_103931.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_105653.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_102331.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_104605.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_101553.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_102631.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_103731.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_103105.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_103832.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_102531.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_102931.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_104905.gtfs
# Processing file 20190603_10.pkl took 0:04:11.529217
# Error with file 201906/20190603/gtfs_nqrw_20190603_113055.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_110104.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_114528.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_113904.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_113518.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_115505.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_114405.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_112128.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_113829.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_114004.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_114104.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_115355.gtfs
# Processing file 20190603_11.pkl took 0:04:12.397169
# Error with file 201906/20190603/gtfs_nqrw_20190603_122317.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_121917.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_122908.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_122708.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_121031.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_122929.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_121507.gtfs
# Processing file 20190603_12.pkl took 0:04:16.655535
# Error with file 201906/20190603/gtfs_bdfm_20190603_135455.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_132923.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_132132.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_130932.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_131742.gtfs
# Processing file 20190603_13.pkl took 0:04:23.375210
# Error with file 201906/20190603/gtfs_nqrw_20190603_145108.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_145719.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_145928.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_145108.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_142007.gtfs
# Processing file 20190603_14.pkl took 0:04:11.301897
# Error with file 201906/20190603/gtfs_ace_20190603_153943.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_155003.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_150330.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_153301.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_152602.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_151029.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_150119.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_154220.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_155532.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_150229.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_155844.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_155831.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_152920.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_153631.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_151329.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_151919.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_154131.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_150631.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_155734.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_154503.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_153744.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_150851.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_154131.gtfs
# Processing file 20190603_15.pkl took 0:04:09.938798
# Error with file 201906/20190603/gtfs_nqrw_20190603_160232.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_161706.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_165719.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_164207.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_163303.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_164454.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_161105.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_161332.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_165438.gtfs
# Error with file 201906/20190603/gtfs_ace_20190603_161306.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_161626.gtfs
# Error with file 201906/20190603/gtfs_nqrw_20190603_165228.gtfs
# Error with file 201906/20190603/gtfs_bdfm_20190603_160852.gtfs
# Processing file 20190603_16.pkl took 0:04:15.799965
# Error with file 201906/20190603/gtfs_ace_20190603_170240.gtfs
# Processing file 20190603_17.pkl took 0:00:05.217283
# Processing file 20190603_18.pkl took 0:00:00.106368
# Processing file 20190603_19.pkl took 0:00:00.516395
# Processing file 20190603_20.pkl took 0:00:00.208616
# Processing file 20190603_21.pkl took 0:00:00.644516
# Error with file 201906/20190603/gtfs_7_20190603_220326.gtfs
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/envs/py3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'trip_update.stop_time_update'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in create_hourly_files(data_dir, output_dir)
#
# <ipython-input-2-dc43ac2829c3> in parse_data(realtime_data)
#      27
#      28     # Get rid of null stop_time_updates
# ---> 29     df = df[~df['trip_update.stop_time_update'].isnull()]
#      30
#      31     idx = df.index.repeat(df['trip_update.stop_time_update'].str.len())
#
# /opt/conda/envs/py3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /opt/conda/envs/py3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'trip_update.stop_time_update'
