# %%
import pandas as pd 
import geopandas as gp
import altair as alt 
import gpdvega 
import json
import matplotlib.pyplot as plt
alt.renderers.enable('notebook') # render for Jupyter Notebook

DATA_DIR = '/nas/dft/ire/stuartlynn/MTA_ACCESSIBILITY/MTAAlertScraper-master/data/'
DATA_DIR2 = '/nas/dft/ire/kmohan/hackday_2019_q4_mta_accessibility/data/'

turnstile = pd.read_pickle(DATA_DIR2+"turnstile_new.pkl.gz")

outages = pd.read_csv(DATA_DIR+"outages.csv.gz" )
outages['Outage start'] = pd.to_datetime(outages['Outage start'], format='%Y-%m-%d %H:%M:%S')
outages['Outage end'] = pd.to_datetime(outages['Outage end'], format='%Y-%m-%d %H:%M:%S')

daily_data = (outages.groupby(['Equipment number', 'Station',outages['Outage start'].dt.floor('d')])
                    .Duration.sum()
                    .reset_index()
                    .assign(day = lambda x: x['Outage start'].dt.day, month = lambda x: x['Outage start'].dt.month)
                    .set_index('Equipment number'))

remote_station = pd.read_excel(DATA_DIR + 'Remote-Booth-Station.xls')

# %%
turnstile.head()

# %%
subway_turnstile = pd.read_csv(DATA_DIR+'subway_turnstile_join.csv')

# %%
subway_turnstile[subway_turnstile['name']=='Union Sq - 14th St']

# %%
def join_st(station):
    atlantic_ave = turnstile[(turnstile.STATION==station) &  (turnstile.datetime.dt.year==2019)]
    turnstile_data_by_day = atlantic_ave[ (atlantic_ave.entry_diff.abs() < 2000) & (atlantic_ave.exit_diff.abs() < 2000) ].assign(day=atlantic_ave.datetime.dt.day, month = atlantic_ave.datetime.dt.month).groupby(['day','month']).sum()[['entry_diff', 'exit_diff']].reset_index()

    out_station = get_outage_station(station)
    atl_daily_outage = daily_data[daily_data['Station'] == out_station]

    atl_daily_outage = atl_daily_outage.reset_index()
    joined = pd.merge(atl_daily_outage, turnstile_data_by_day, on=['day', 'month'])
    joined.sort_values(by=['month', 'day'])

# %%
eem = pd.read_csv('EE_master_list.csv')
eem.rename(columns={'st_name_opd_format': 'name'}, inplace=True)
mapping = pd.merge(eem, subway_turnstile, on='name')
# [['station_name', 'name', 'station']].drop_duplicates()


t_ust = turnstile[['UNIT', 'STATION']].drop_duplicates()

t_ust = t_ust.rename(columns={'UNIT': 'Remote'})

# t_ust[t_ust['STATION'].str.contains('34')]

tst = t_ust.set_index('Remote').join(remote_station.set_index('Remote'))[['STATION', 'Station', 'Line Name']]

tst.rename(columns={'STATION': 'Turnstile_station', 'Station': 'remote_station'}, inplace=True)

tst.reset_index(inplace=True)

tst['Line Name'] = tst['Line Name'].astype('str')

sst = pd.merge(tst, subway_turnstile, how='left', left_on=['remote_station', 'Line Name'], right_on=['station', 'line_name'])[['Turnstile_station', 'remote_station', 'name', 'line', 'Line Name']]

sst.rename(columns={'name': 'subway_station'}, inplace=True)

tst[tst['Turnstile_station'].str.contains('125')]

tmp = sst.fillna('')

# %%
tmp[tmp['remote_station'].str.contains('125')]

# %%
tst[tst['Turnstile_station'].str.contains('125')]['Line Name'].unique()
# Out:
# array(['1', 'ACBD', '456', '23'], dtype=object)

# %%
stmp = subway_turnstile.fillna('')
stmp[stmp['station'].str.contains('125')]['line_name'].unique()
# Out:
# array(['23', '1', '456'], dtype=object)

# %%
eem.head()

# %%
fst = pd.merge(sst, eem, how='left', left_on=['subway_station', 'line'], right_on=['name', 'line'])[['Turnstile_station', 'remote_station', 'subway_station', 'line', 'station_name', 'equipment_id', 'name', 'Line Name']]

# %%
fst[fst.Turnstile_station.str.contains('ATL')]

# %%
fst.to_csv('turnstile_to_outage_line_name.csv')

# %%
fst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2202 entries, 0 to 2201
# Data columns (total 8 columns):
# Turnstile_station    2202 non-null object
# remote_station       2198 non-null object
# subway_station       1977 non-null object
# line                 1977 non-null object
# station_name         1406 non-null object
# equipment_id         1406 non-null object
# name                 1406 non-null object
# Line Name            2202 non-null object
# dtypes: object(8)
# memory usage: 154.8+ KB

# %%
eem[eem['station_name'].str.contains('White')]

# %%
def get_outage_station(st):
    return fst[fst['Turnstile_station'] == st]['name']

# %%
tout = pd.merge(daily_data.reset_index(), fst, how='left', left_on='Equipment number', right_on='equipment_id')

# %%
tout.head()

# %%
turnstile.reset_index(inplace=True)

# %%
t19 = turnstile[turnstile.datetime.dt.year==2019]
turnstile_data_by_day = t19[(t19.entry_diff_abs < 4000) & (t19.exit_diff_abs < 4000)].assign(day=t19.datetime.dt.day, month = t19.datetime.dt.month).groupby(['day','month', 'STATION', 'LINENAME']).sum()[['entry_diff_abs', 'exit_diff_abs']].reset_index()
turnstile_data_by_day.head(20)

# %%
tout.head()

# %%
e_turns = pd.merge(tout, turnstile_data_by_day, how='left', left_on=['Turnstile_station', 'line' , 'month', 'day'], right_on=['STATION', 'LINENAME', 'month', 'day'])

# %%
e_turns.columns
# Out:
# Index(['Equipment number', 'Station', 'Outage start', 'Duration', 'day',
#        'month', 'Turnstile_station', 'remote_station', 'subway_station',
#        'line', 'station_name', 'equipment_id', 'name', 'Line Name', 'STATION',
#        'LINENAME', 'entry_diff_abs', 'exit_diff_abs'],
#       dtype='object')

# %%
e_turns.drop(['Turnstile_station', 'remote_station', 'name','equipment_id'], axis=1, inplace=True)

# %%
e_turns.head()

# %%
e_turns['flow_abs'] = e_turns['entry_diff_abs'] + e_turns['exit_diff_abs']

# %%
e_turns['Duration'].describe()
# Out:
# count    80906.000000
# mean         4.627790
# std          4.639232
# min          0.000278
# 25%          1.459444
# 50%          3.200278
# 75%          5.901111
# max         37.922500
# Name: Duration, dtype: float64

# %%
e_turns['Duration'] = e_turns['Duration'] / 24

# %%
e_turns['score'] = e_turns['Duration'] * e_turns['flow_abs']
result = e_turns.groupby(['Equipment number', 'Station']).sum()['score'].sort_values( ascending=False)

# %%
result.plot()

# %%
e_turns.head()

# %%
t19.head()

# %%
turn_avg = turnstile_data_by_day.groupby(['STATION', 'LINENAME']).mean()[['entry_diff_abs', 'exit_diff_abs']].reset_index()

# %%
turn_avg['flow_abs'] = turn_avg['entry_diff_abs'] + turn_avg['exit_diff_abs']

# %%
turn_avg.head()

# %%
e_turns.head()

# %%
metric_day = pd.merge(e_turns, turn_avg, how='left', left_on=['STATION', 'LINENAME'], right_on=['STATION', 'LINENAME'])

# %%
metric_day['day_score'] = metric_day['score'] / metric_day['flow_abs_y']

# %%
metric_day.sort_values(by='day_score', ascending=False).to_csv('final_score.csv', index=None)

# %%
metric_day[metric_day['Equipment number'] == 'ES217']

# %%
geo_final_score.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-1924d2ba75ba> in <module>
# ----> 1 geo_final_score.plot()
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2942                           sort_columns=sort_columns, **kwds)
#    2943     __call__.__doc__ = plot_frame.__doc__
#    2944
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1971                  yerr=yerr, xerr=xerr,
#    1972                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1973                  **kwds)
#    1974
#    1975
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1799         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1800
# -> 1801     plot_obj.generate()
#    1802     plot_obj.draw()
#    1803     return plot_obj.result
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/pandas/plotting/_core.py in generate(self)
#     255
#     256         for ax in self.axes:
# --> 257             self._post_plot_logic_common(ax, self.data)
#     258             self._post_plot_logic(ax, self.data)
#     259
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/pandas/plotting/_core.py in _post_plot_logic_common(self, ax, data)
#     397             self._apply_axis_properties(ax.xaxis, rot=self.rot,
#     398                                         fontsize=self.fontsize)
# --> 399             self._apply_axis_properties(ax.yaxis, fontsize=self.fontsize)
#     400
#     401             if hasattr(ax, 'right_ax'):
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/pandas/plotting/_core.py in _apply_axis_properties(self, axis, rot, fontsize)
#     470
#     471     def _apply_axis_properties(self, axis, rot=None, fontsize=None):
# --> 472         labels = axis.get_majorticklabels() + axis.get_minorticklabels()
#     473         for label in labels:
#     474             if rot is not None:
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1243     def get_majorticklabels(self):
#    1244         'Return a list of Text instances for the major ticklabels'
# -> 1245         ticks = self.get_major_ticks()
#    1246         labels1 = [tick.label1 for tick in ticks if tick.label1On]
#    1247         labels2 = [tick.label2 for tick in ticks if tick.label2On]
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1394         'get the tick instances; grow as necessary'
#    1395         if numticks is None:
# -> 1396             numticks = len(self.get_major_locator()())
#    1397
#    1398         while len(self.majorTicks) < numticks:
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/dates.py in __call__(self)
#    1247     def __call__(self):
#    1248         'Return the locations of the ticks'
# -> 1249         self.refresh()
#    1250         return self._locator()
#    1251
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/dates.py in refresh(self)
#    1267     def refresh(self):
#    1268         'Refresh internal information based on current limits.'
# -> 1269         dmin, dmax = self.viewlim_to_dt()
#    1270         self._locator = self.get_locator(dmin, dmax)
#    1271
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#    1024                              'often happens if you pass a non-datetime '
#    1025                              'value to an axis that has datetime units'
# -> 1026                              .format(vmin))
#    1027         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1028
#
# ValueError: view limit minimum -36868.5 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f61f90ad378> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/pyplot.py in post_execute()
#     147             def post_execute():
#     148                 if matplotlib.is_interactive():
# --> 149                     draw_all()
#     150
#     151             # IPython >= 2
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     134         for f_mgr in cls.get_all_fig_managers():
#     135             if force or f_mgr.canvas.figure.stale:
# --> 136                 f_mgr.canvas.draw_idle()
#     137
#     138 atexit.register(Gcf.destroy_all)
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2053         if not self._is_idle_drawing:
#    2054             with self._idle_draw_cntx():
# -> 2055                 self.draw(*args, **kwargs)
#    2056
#    2057     def draw_cursor(self, event):
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     431             # if toolbar:
#     432             #     toolbar.set_cursor(cursors.WAIT)
# --> 433             self.figure.draw(self.renderer)
#     434             # A GUI class may be need to update a window using this draw, so
#     435             # don't forget to call the superclass.
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1473
#    1474             mimage._draw_list_compositing_images(
# -> 1475                 renderer, self, artists, self.suppressComposite)
#    1476
#    1477             renderer.close_group('figure')
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2605             renderer.stop_rasterizing()
#    2606
# -> 2607         mimage._draw_list_compositing_images(renderer, self, artists)
#    2608
#    2609         renderer.close_group('axes')
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1188         renderer.open_group(__name__)
#    1189
# -> 1190         ticks_to_draw = self._update_ticks(renderer)
#    1191         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1192                                                                 renderer)
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/axis.py in _update_ticks(self, renderer)
#    1026
#    1027         interval = self.get_view_interval()
# -> 1028         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1029         if self._smart_bounds and tick_tups:
#    1030             # handle inverted limits
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/axis.py in iter_ticks(self)
#     969         Iterate through all of the major and minor ticks.
#     970         """
# --> 971         majorLocs = self.major.locator()
#     972         majorTicks = self.get_major_ticks(len(majorLocs))
#     973         self.major.formatter.set_locs(majorLocs)
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/dates.py in __call__(self)
#    1247     def __call__(self):
#    1248         'Return the locations of the ticks'
# -> 1249         self.refresh()
#    1250         return self._locator()
#    1251
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/dates.py in refresh(self)
#    1267     def refresh(self):
#    1268         'Refresh internal information based on current limits.'
# -> 1269         dmin, dmax = self.viewlim_to_dt()
#    1270         self._locator = self.get_locator(dmin, dmax)
#    1271
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#    1024                              'often happens if you pass a non-datetime '
#    1025                              'value to an axis that has datetime units'
# -> 1026                              .format(vmin))
#    1027         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1028
#
# ValueError: view limit minimum -36868.5 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# --> 177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
#     179                                 for label in axis.get_ticklabels()])
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in <listcomp>(.0)
#     177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# --> 179                                 for label in axis.get_ticklabels()])
#     180         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     181             # there are one or more tick labels, all with the same lightness
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1289         if minor:
#    1290             return self.get_minorticklabels()
# -> 1291         return self.get_majorticklabels()
#    1292
#    1293     def get_majorticklines(self):
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1243     def get_majorticklabels(self):
#    1244         'Return a list of Text instances for the major ticklabels'
# -> 1245         ticks = self.get_major_ticks()
#    1246         labels1 = [tick.label1 for tick in ticks if tick.label1On]
#    1247         labels2 = [tick.label2 for tick in ticks if tick.label2On]
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1394         'get the tick instances; grow as necessary'
#    1395         if numticks is None:
# -> 1396             numticks = len(self.get_major_locator()())
#    1397
#    1398         while len(self.majorTicks) < numticks:
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/dates.py in __call__(self)
#    1247     def __call__(self):
#    1248         'Return the locations of the ticks'
# -> 1249         self.refresh()
#    1250         return self._locator()
#    1251
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/dates.py in refresh(self)
#    1267     def refresh(self):
#    1268         'Refresh internal information based on current limits.'
# -> 1269         dmin, dmax = self.viewlim_to_dt()
#    1270         self._locator = self.get_locator(dmin, dmax)
#    1271
#
# /nas/dft/ire/tsbeakerx/.conda/shared-envs/data-clinic/lib/python3.6/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#    1024                              'often happens if you pass a non-datetime '
#    1025                              'value to an axis that has datetime units'
# -> 1026                              .format(vmin))
#    1027         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1028
#
# ValueError: view limit minimum -36868.5 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units

# %%
valid_turnstile = turnstile[(turnstile.entry_diff.abs() < 3000) & (turnstile.exit_diff.abs() < 3000)]        # Get rid of outliers
daily_station_counts = valid_turnstile.groupby(['STATION','LINENAME', valid_turnstile.datetime.dt.floor('d')]).sum()[[    # Group by station and day and sum
    'entry_diff',                                                                                              # Select only the entry and exit columns
    'exit_diff'
]].reset_index()       

geo_joined_daily_data = gp.GeoDataFrame(
     pd.merge(
        daily_station_counts,
        subway_turnstile, 
        left_on=['STATION', 'LINENAME'],
        right_on=['station','line_name']
    ).set_index('datetime')
)

# %%
from shapely import wkt

# %%
geo_stations.geometry = geo_stations.geometry.apply(wkt.loads)

# %%
# Out:
# subway_station  line
# 125th St        1                  0.261263
#                 4-5-6-6 Express         NaN
#                 A-B-C-D                 NaN
# 135th St        2-3                     NaN
# 145th St        A-B-C-D                 NaN
# Name: day_score, dtype: float64

# %%
consolidated_metric = metric_day.groupby(['subway_station','line']).mean()['day_score']
# consolidated_metric.reset_index().rename(columns={'subway_station':'name'},inplace=True)

# %%
consolidated_metric = consolidated_metric.reset_index().rename(columns={'subway_station': 'name'})

# %%
geo_plot_df = geo_stations.merge(consolidated_metric,on='name')

# %%
geo_plot_df.fillna(0,inplace=True)

# %%
geo_final_score = gp.merge(consolidated_metric, geo_stations, how="left", left_on="subway_station", right_on="name")
geo_final_score.dropna(inplace=True)
geo_final_score['geometry'] = geo_final_score['geometry'].apply(wkt.loads)
geo_final_score.groupby()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-bf408baf4f45> in <module>
# ----> 1 geo_final_score = gp.merge(consolidated_metric, geo_stations, how="left", left_on="subway_station", right_on="name")
#       2 geo_final_score.dropna(inplace=True)
#       3 geo_final_score['geometry'] = geo_final_score['geometry'].apply(wkt.loads)
#       4 geo_final_score.groupby()
#
# AttributeError: module 'geopandas' has no attribute 'merge'

# %%
lines = gp.read_file(DATA_DIR+'Subway Lines.geojson')
fig,ax = plt.subplots(figsize=(15,15))
lines.plot(ax=ax, legend=True, alpha=0.2)
geo_plot_df.plot(column='day_score', ax=ax, legend=True)

# %%
geo_joined_daily_data.head()

# %%
geo_stations = geo_joined_daily_data[['name', 'line', 'geometry']].drop_duplicates()
