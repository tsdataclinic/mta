# %%
from igraph import *
import pandas as pd
import numpy as np
import matplotlib

# %matplotlib inline

# %%
subway_graphs = Graph.Read_GraphML('../../data/processed/mta-elevators.graphml')

# %%
subway_graphs.vs.attributes()
# Out:
# ['label', 'node_type', 'id']

# %%
subway_graphs.vs['label'][subway_graphs.vs['node_type'] == 'street']
# Out:
# '125 St'

# %%
override = pd.read_csv('../../data/raw/elevator-override.csv')

# %%
override.drop(columns=['Unnamed: 0'],inplace=True)

# %%
override
# Out:
#                            station_name equipment_id             from  \
# 0                          Howard Beach       EL491X           Street
# 1                          Howard Beach       EL490X           Street
# 2                          Howard Beach       EL495X        Mezzanine
# 3                          Howard Beach       EL494X        Mezzanine
# 4                          Howard Beach       EL493X        Mezzanine
# 5                          Howard Beach       EL492X        Mezzanine
# 6                    World Trade Center        EL326           Street
# 7                    World Trade Center        EL23X           Street
# 8                          34 St - Penn        EL225           Street
# 9                          34 St - Penn        EL226        Mezzanine
# 10                         34 St - Penn        EL227        Mezzanine
# 11                         34 St - Penn        EL228        Mezzanine
# 12                         34 St - Penn        EL34X           Street
# 13                         34 St - Penn        EL216        Mezzanine
# 14                         34 St - Penn        EL215        Mezzanine
# 15                         34 St - Penn        EL214        Mezzanine
# 16                 Lexington Av / 63 St        EL401           Street
# 17                 Lexington Av / 63 St        EL444           Street
# 18                 Lexington Av / 63 St        EL402    Mezzanine 401
# 19                 Lexington Av / 63 St        EL440    Mezzanine 444
# 20                 Lexington Av / 63 St        EL441    Mezzanine 444
# 21                 Lexington Av / 63 St        EL442    Mezzanine 444
# 22                 Lexington Av / 63 St        EL443    Mezzanine 444
# 23                        Kings Highway        EL761           Street
# 24       Broadway-Lafayette/Bleecker St        EL328           Street
# 25       Broadway-Lafayette/Bleecker St        EL329         Platform
# 26       Broadway-Lafayette/Bleecker St        EL331         Platform
# 27       Broadway-Lafayette/Bleecker St        EL332         Platform
# 28       Broadway-Lafayette/Bleecker St        EL330         Platform
# 29  42 St - Port Authority Bus Terminal       EL288X           Street
# 30  42 St - Port Authority Bus Terminal       EL289X           Street
# 31  42 St - Port Authority Bus Terminal       EL291X           Street
# 32  42 St - Port Authority Bus Terminal       EL290X             Mezz
# 33                     Times Sq - 42 St       EL231X           Street
# 34                     Times Sq - 42 St       EL232X        Mezzanine
# 35                     Times Sq - 42 St        EL233        Mezzanine
# 36                     Times Sq - 42 St        EL229        Mezzanine
# 37                     Times Sq - 42 St        EL230        Mezzanine
# 38            West 4 St - Washington Sq        EL333           Street
# 39            West 4 St - Washington Sq        EL336        Mezzanine
# 40            West 4 St - Washington Sq        EL335  Lower Mezzanine
# 41            West 4 St - Washington Sq        EL336  Lower Mezzanine
#
#                  to                                      platform_id
# 0         Mezzanine                                              NaN
# 1         Mezzanine                                              NaN
# 2          Platform                                          A-north
# 3          Platform                                          A-north
# 4          Platform                                          A-south
# 5          Platform                                   A-far rockaway
# 6          Platform                                          E-north
# 7          Platform                                          E-north
# 8          Platform                                  C-north/E-north
# 9          Platform                                  C-north/E-north
# 10         Platform                                  A-north/A-south
# 11         Platform                                  C-south/E-south
# 12        Mezzanine                                              NaN
# 13         Platform                                          1-south
# 14         Platform                  2-north/2-south/3-north/3-south
# 15         Platform                                          1-north
# 16    Mezzanine 401                                              NaN
# 17    Mezzanine 444                                              NaN
# 18         Platform                  F-north/Q-north/F-south/Q-south
# 19         Platform                  F-north/Q-north/F-south/Q-south
# 20         Platform                  F-north/Q-north/F-south/Q-south
# 21         Platform                  F-north/Q-north/F-south/Q-south
# 22         Platform                  F-north/Q-north/F-south/Q-south
# 23         Platform  H-brigton beach/Q-coney island/B-brighton beach
# 24      Mezzanine A                                          6-south
# 25      Mezzanine A                  B-north/D-north/F-north/M-north
# 26         Platform                                          6-north
# 27         Platform                                          6-north
# 28      Mezzanine A                  B-south/D-south/F-south/M-south
# 29         Platform  A-south/C-south/E-south/A-north/C-north/E-north
# 30         Platform  A-south/C-south/E-south/A-north/C-north/E-north
# 31             Mezz                                              NaN
# 32         Platform  A-south/C-south/E-south/A-north/C-north/E-north
# 33        Mezzanine                                   S-grandcentral
# 34         Platform            7-east/7-west/1-south/2-south/3-south
# 35         Platform                          1-north/2-north/3-north
# 36         Platform                  N-south/Q-south/R-south/W-south
# 37         Platform                  N-north/Q-north/R-north/W-north
# 38        Mezzanine  A-south/C-south/E-south/A-north/C-north/E-north
# 39  Lower Mezzanine                                              NaN
# 40         Platform                  B-north/D-north/F-north/M-north
# 41         Platform                  B-south/D-south/F-south/M-south

# %%
# override.loc[23] = ['Kings Highway', 'EL761', 'Street','Platform','H-brigton beach/Q-coney island/B-brighton beach']

# %%
# override.loc[24] = ['Broadway-Lafayette/Bleecker St', 'EL328', 'Street','Mezzanine A','6-south']
# override.loc[25] = ['Broadway-Lafayette/Bleecker St', 'EL329', 'Platform','Mezzanine A','B-north/D-north/F-north/M-north']
# override.loc[26] = ['Broadway-Lafayette/Bleecker St', 'EL331', 'Platform','Platform','6-north']
# override.loc[27] = ['Broadway-Lafayette/Bleecker St', 'EL332', 'Platform','Platform','6-north']
# override.loc[28] = ['Broadway-Lafayette/Bleecker St', 'EL330', 'Platform','Mezzanine A','B-south/D-south/F-south/M-south']

# %%
# override.loc[29] = ['42 St - Port Authority Bus Terminal', 'EL288X', 'Street','Platform','A-south/C-south/E-south/A-north/C-north/E-north']
# override.loc[30] = ['42 St - Port Authority Bus Terminal', 'EL289X', 'Street','Platform','A-south/C-south/E-south/A-north/C-north/E-north']
# override.loc[31] = ['42 St - Port Authority Bus Terminal', 'EL291X', 'Street','Mezz',np.NaN]
# override.loc[32] = ['42 St - Port Authority Bus Terminal', 'EL290X', 'Mezz','Platform','A-south/C-south/E-south/A-north/C-north/E-north']

# %%
# override.loc[33] = ['Times Sq - 42 St', 'EL231X', 'Street','Mezzanine','S-grandcentral']
# override.loc[34] = ['Times Sq - 42 St', 'EL232X', 'Mezzanine','Platform','7-east/7-west/1-south/2-south/3-south']
# override.loc[35] = ['Times Sq - 42 St', 'EL233', 'Mezzanine','Platform','1-north/2-north/3-north']
# override.loc[36] = ['Times Sq - 42 St', 'EL229', 'Mezzanine','Platform','N-south/Q-south/R-south/W-south']
# override.loc[37] = ['Times Sq - 42 St', 'EL230', 'Mezzanine','Platform','N-north/Q-north/R-north/W-north']

# %%
# override.loc[38] = ['West 4 St - Washington Sq', 'EL333', 'Street','Mezzanine','A-south/C-south/E-south/A-north/C-north/E-north']
# override.loc[39] = ['West 4 St - Washington Sq', 'EL335', 'Mezzanine','Lower Mezzanine',np.NaN]
# override.loc[39] = ['West 4 St - Washington Sq', 'EL336', 'Mezzanine','Lower Mezzanine',np.NaN]
# override.loc[40] = ['West 4 St - Washington Sq', 'EL335', 'Lower Mezzanine','Platform','B-north/D-north/F-north/M-north']
# override.loc[41] = ['West 4 St - Washington Sq', 'EL336', 'Lower Mezzanine','Platform','B-south/D-south/F-south/M-south']

# %%
override.loc[42] = ['59 St - Columbus Cir', 'EL276X', 'Street','Lower Mezzanine','1-south']
override.loc[43] = ['59 St - Columbus Cir', 'EL277', 'Lower Mezzanine','Platform','A-south/B-south/C-south/D-south']
override.loc[44] = ['59 St - Columbus Cir', 'EL280', 'Street','Mezzanine','1-north']
override.loc[45] = ['59 St - Columbus Cir', 'EL279', 'Mezzanine','Platform','A-north/B-north/C-north/D-north']
override.loc[46] = ['59 St - Columbus Cir', 'EL278', 'Lower Mezzanine','Platform','A-north/B-north/C-north/D-north']

# %%
override.to_csv('../../data/raw/elevator-override.csv',index=False)
