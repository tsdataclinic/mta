# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
gpd.__version__
# Out:
# '0.6.1'

# %%
zipcode = gpd.read_file('data/zipcode/ZIP_CODE_040114.shp')
zipcode = zipcode.to_crs({'init': 'epsg:4326'})

# %%
zipcode.plot(column='POPULATION')

# %%
stations =  gpd.read_file('../../data/raw/subway_stations.geojson')

# %%
stations.plot()

# %%
stations.head()
# Out:
#                name                                url           line  \
# 0          Astor Pl  http://web.mta.info/nyct/service/  4-6-6 Express
# 1          Canal St  http://web.mta.info/nyct/service/  4-6-6 Express
# 2           50th St  http://web.mta.info/nyct/service/            1-2
# 3         Bergen St  http://web.mta.info/nyct/service/          2-3-4
# 4  Pennsylvania Ave  http://web.mta.info/nyct/service/            3-4
#
#   objectid                                              notes  \
# 0        1  4 nights, 6-all times, 6 Express-weekdays AM s...
# 1        2  4 nights, 6-all times, 6 Express-weekdays AM s...
# 2        3                              1-all times, 2-nights
# 3        4           4-nights, 3-all other times, 2-all times
# 4        5                        4-nights, 3-all other times
#
#                      geometry
# 0  POINT (-73.99107 40.73005)
# 1  POINT (-74.00019 40.71880)
# 2  POINT (-73.98385 40.76173)
# 3  POINT (-73.97500 40.68086)
# ...

# %%
stations_in_zipcode = gpd.sjoin(stations, zipcode, how="inner",op="intersects")

# %%
stations_in_zipcode.head()
# Out:
#                           name                                url  \
# 0                     Astor Pl  http://web.mta.info/nyct/service/
# 104         Union Sq - 14th St  http://web.mta.info/nyct/service/
# 370  Lower East Side - 2nd Ave  http://web.mta.info/nyct/service/
# 378         Union Sq - 14th St  http://web.mta.info/nyct/service/
# 382                    3rd Ave  http://web.mta.info/nyct/service/
#
#                 line objectid  \
# 0      4-6-6 Express        1
# 104  4-5-6-6 Express      105
# 370                F      371
# 378          N-Q-R-W      379
# 382                L      383
#
#                                                  notes  \
# 0    4 nights, 6-all times, 6 Express-weekdays AM s...
# 104  4,6-all times, 5-all times exc nights, 6 Expre...
# 370                                        F-all times
# 378              N,Q-all times, R-all times exc nights
# 382                                        L-all times
#
# ...
